# %% [markdown]
# <a href="https://colab.research.google.com/github/DeviShree2006/LAB-PRACTICAL-AI/blob/main/EXP_NO_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

def heuristic(state):
    goal = [1, 2, 3, 4, 5, 6, 7, 8, 0]
    distance = 0

    for i in range(9):
        if state[i] != 0:
            goal_pos = goal.index(state[i])
            distance += abs(i // 3 - goal_pos // 3)
            distance += abs(i % 3 - goal_pos % 3)

    return distance


def get_neighbors(state):
    neighbors = []
    zero = state.index(0)

    row = zero // 3
    col = zero % 3

    moves = [
        (-1, 0),
        (1, 0),
        (0, -1),
        (0, 1)
    ]

    for dr, dc in moves:
        new_row = row + dr
        new_col = col + dc

        if 0 <= new_row < 3 and 0 <= new_col < 3:
            new_zero = new_row * 3 + new_col

            new_state = state.copy()
            new_state[zero], new_state[new_zero] = \
                new_state[new_zero], new_state[zero]

            neighbors.append(new_state)

    return neighbors


def solve(start):
    goal = [1, 2, 3, 4, 5, 6, 7, 8, 0]

    priority_queue = []
    heapq.heappush(priority_queue,
                   (heuristic(start), 0, start, []))

    visited = set()

    while priority_queue:
        f, g, state, path = heapq.heappop(priority_queue)

        state_tuple = tuple(state)

        if state_tuple in visited:
            continue

        visited.add(state_tuple)

        path = path + [state]

        if state == goal:
            return path

        for neighbor in get_neighbors(state):
            if tuple(neighbor) not in visited:
                new_g = g + 1
                new_f = new_g + heuristic(neighbor)

                heapq.heappush(
                    priority_queue,
                    (new_f, new_g, neighbor, path)
                )

    return None


def display(state):
    for i in range(0, 9, 3):
        print(state[i:i+3])
    print()


start = [1, 2, 3,
         4, 0, 6,
         7, 5, 8]

solution = solve(start)

if solution:
    print("Solution:")
    for state in solution:
        display(state)
else:
    print("No solution found")
# Out:
# Solution:
# [1, 2, 3]
# [4, 0, 6]
# [7, 5, 8]
#
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]
