# %% [markdown]
# <a href="https://colab.research.google.com/github/DeviShree2006/LAB-PRACTICAL-AI/blob/main/EXP_NO_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence = input("Enter a sentence: ")
words = sorted(sentence.split())
sorted_sentence = " ".join(words)
print("Sorted sentence:", sorted_sentence)
# Out:
# Enter a sentence: IT IS AN APPLE
# Sorted sentence: AN APPLE IS IT
