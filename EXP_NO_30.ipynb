# %% [markdown]
# <a href="https://colab.research.google.com/github/DeviShree2006/LAB-PRACTICAL-AI/blob/main/EXP_NO_30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
planets = {
    "Mercury": "Rocky",
    "Venus": "Rocky",
    "Earth": "Rocky",
    "Mars": "Rocky",
    "Jupiter": "Gas",
    "Saturn": "Gas",
    "Uranus": "Gas",
    "Neptune": "Gas"
}

print("Planets and Types:")

for planet, planet_type in planets.items():
    print(planet, ":", planet_type)
# Out:
# Planets and Types:
# Mercury : Rocky
# Venus : Rocky
# Earth : Rocky
# Mars : Rocky
# Jupiter : Gas
# Saturn : Gas
# Uranus : Gas
# Neptune : Gas
