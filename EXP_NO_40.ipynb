# %% [markdown]
# <a href="https://colab.research.google.com/github/DeviShree2006/LAB-PRACTICAL-AI/blob/main/EXP_NO_40.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
html = """
<!DOCTYPE html>
<html>

<head>
    <title>Artificial Intelligence Blog</title>
</head>

<body>

    <h1>Artificial Intelligence</h1>

    <h2>Introduction</h2>

    <p>
        Artificial Intelligence is a technology that enables
        computers to learn, reason and make decisions.
    </p>

    <h2>AI Applications</h2>

    <p>
        AI is used in healthcare, education, banking,
        transportation and entertainment.
    </p>

    <h2>Useful AI Resources</h2>

    <a href="https://www.google.com">Visit Google</a>

    <br><br>

    <a href="https://www.wikipedia.org">
        Learn more from Wikipedia
    </a>

    <h2>AI Image</h2>

    <img src="https://via.placeholder.com/400"
         alt="Artificial Intelligence"
         width="400">

    <h2>Conclusion</h2>

    <p>
        Artificial Intelligence is becoming an important
        part of modern technology.
    </p>

</body>

</html>
"""

# Create HTML file
with open("ai_blog.html", "w") as file:
    file.write(html)

print("AI Blog created successfully!")
print("Open 'ai_blog.html' in a web browser.")
# Out:
# AI Blog created successfully!
# Open 'ai_blog.html' in a web browser.
