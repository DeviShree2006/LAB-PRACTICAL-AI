# %% [markdown]
# <a href="https://colab.research.google.com/github/DeviShree2006/LAB-PRACTICAL-AI/blob/main/EXP_NO_31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hanoi(n, source, destination, auxiliary):

    if n == 1:
        print("Move disk from", source, "to", destination)
        return

    hanoi(n - 1, source, auxiliary, destination)

    print("Move disk from", source, "to", destination)

    hanoi(n - 1, auxiliary, destination, source)


n = int(input("Enter number of disks: "))

hanoi(n, "A", "C", "B")
# Out:
# Enter number of disks: 3
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
