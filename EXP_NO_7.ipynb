# %% [markdown]
# <a href="https://colab.research.google.com/github/DeviShree2006/LAB-PRACTICAL-AI/blob/main/EXP_NO_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Define the sets
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}

# Display sets
print("Set 1:", set1)
print("Set 2:", set2)

# Intersection
intersection_set = set1.intersection(set2)
print("Intersection of set1 and set2:", intersection_set)

# Union
union_set = set1.union(set2)
print("Union of set1 and set2:", union_set)

# Difference
difference_set = set1.difference(set2)
print("Difference between set1 and set2:", difference_set)

# Symmetric Difference
symmetric_difference_set = set1.symmetric_difference(set2)
print("Symmetric difference between set1 and set2:", symmetric_difference_set)

# Subset check
subset_check = set1.issubset(set2)
print("Set 1 is subset of set 2:", subset_check)
# Out:
# Set 1: {1, 2, 3, 4, 5}
# Set 2: {4, 5, 6, 7, 8}
# Intersection of set1 and set2: {4, 5}
# Union of set1 and set2: {1, 2, 3, 4, 5, 6, 7, 8}
# Difference between set1 and set2: {1, 2, 3}
# Symmetric difference between set1 and set2: {1, 2, 3, 6, 7, 8}
# Set 1 is subset of set 2: False
