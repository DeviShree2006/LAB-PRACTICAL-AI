# %% [markdown]
# <a href="https://colab.research.google.com/github/DeviShree2006/LAB-PRACTICAL-AI/blob/main/EXP_NO_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
database = [
    ("Ravi", "AI", "AI101"),
    ("Priya", "DBMS", "DB101"),
    ("Amit", "Networks", "CN101"),
    ("Anitha", "Python", "PY101")
]

print("Student  Subject  Code")

for student, subject, code in database:
    print(student, "   ", subject, "   ", code)
# Out:
# Student  Subject  Code
# Ravi     AI     AI101
# Priya     DBMS     DB101
# Amit     Networks     CN101
# Anitha     Python     PY101
