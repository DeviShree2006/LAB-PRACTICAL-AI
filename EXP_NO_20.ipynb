# %% [markdown]
# <a href="https://colab.research.google.com/github/DeviShree2006/LAB-PRACTICAL-AI/blob/main/EXP_NO_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

def astar(graph, heuristic, start, goal):

    open_list = []

    heapq.heappush(open_list, (0, start))

    g_cost = {start: 0}
    parent = {start: None}

    while open_list:

        f, current = heapq.heappop(open_list)

        if current == goal:

            path = []

            while current is not None:
                path.append(current)
                current = parent[current]

            return path[::-1], g_cost[goal]

        for neighbour, cost in graph[current]:

            new_cost = g_cost[current] + cost

            if neighbour not in g_cost or new_cost < g_cost[neighbour]:

                g_cost[neighbour] = new_cost
                f_cost = new_cost + heuristic[neighbour]

                heapq.heappush(
                    open_list,
                    (f_cost, neighbour)
                )

                parent[neighbour] = current

    return None


graph = {
    'A': [('B', 1), ('C', 4)],
    'B': [('D', 2)],
    'C': [('D', 1)],
    'D': [('G', 3)],
    'G': []
}

heuristic = {
    'A': 5,
    'B': 4,
    'C': 2,
    'D': 3,
    'G': 0
}

path, cost = astar(graph, heuristic, 'A', 'G')

print("Best Path:", " -> ".join(path))
print("Total Cost:", cost)
# Out:
# Best Path: A -> B -> D -> G
# Total Cost: 6
